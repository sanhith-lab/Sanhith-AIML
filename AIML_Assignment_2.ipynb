# %% [markdown]
# <a href="https://colab.research.google.com/github/sanhith-lab/Sanhith-AIML/blob/main/AIML_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Visulization of data using matplotlib ,pyplot
import pandas as pd
people=['Sanhith','Rahul','Ravi','sunny','abhi']
age=[25,30,35,33,23]
height=[145,55,65,234,173]
weight=[45,55,63,65,92]
data={
    'Name':people,
    'Age':age,
    'Height':height,
    'Weight':weight
    }
df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Height  Weight
# 0  Sanhith   25     145      45
# 1    Rahul   30      55      55
# 2     Ravi   35      65      63
# 3    sunny   33     234      65
# 4     abhi   23     173      92

# %%
# Scatter plot: Age vs Weight
import pandas as pd
import matplotlib.pyplot as plt
people=['Sanhith','Rahul','Ravi','sunny','abhi']
age=[25,30,35,33,23]
height=[145,55,65,234,173]
weight=[45,55,63,65,92]
data={
    'Name':people,
    'Age':age,
    'Height':height,
    'Weight':weight
    }
df=pd.DataFrame(data)
plt.figure(figsize=(10,6))
plt.scatter(df['Age'],df['Weight'],color='blue',marker='o')
plt.title('Scaatter Plot of Age vs Weight')
plt.xlabel('Age(year)')
plt.ylabel('weight(kg)')
plt.grid(True)
plt.show()

# %%
# Bar chartt: Height of individual
import pandas as pd
import matplotlib.pyplot as plt
people=['Sanhith','Rahul','Ravi','sunny','abhi']
age=[25,30,35,33,23]
height=[145,55,65,234,173]
weight=[45,55,63,65,92]
data={
    'Name':people,
    'Age':age,
    'Height':height,
    'Weight':weight
    }
df=pd.DataFrame(data)
plt.figure(figsize=(10,6))
plt.bar(df['Name'],df['Height'],color='orange')
plt.title('Bar chart of individual height')
plt.xlabel('Name')
plt.ylabel('Height(cm)')
plt.show()

# %%
# Bar chartt: Height of individual
import pandas as pd
import matplotlib.pyplot as plt
people=['Sanhith','Rahul','Ravi','sunny','abhi']
age=[25,30,35,33,23]
height=[145,55,65,234,173]
weight=[45,55,63,65,92]
data={
    'Name':people,
    'Age':age,
    'Height':height,
    'Weight':weight
    }
df=pd.DataFrame(data)
# 5. Histogram: Distribution of Age
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=5, color='orange', edgecolor='black')
plt.title('Histogram of Age Distribution')
plt.xlabel('Age (years)')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Generate a Data set for Health Care
people = ['kiran', 'arun', 'vijay', 'varun']
age =[25, 30, 35, 40]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]

data = {
    'Name': people,
    'Age': age,
    'Height': height,
    'Weight': weight
}

df = pd.DataFrame(data)
print(df)

# 3. Scatter Plot: Age vs Weight
plt.figure(figsize=(8, 6))
plt.scatter(df['Age'], df['Weight'], color='blue', marker='o')
plt.title('Scatter Plot of Age vs Weight')
plt.xlabel('Age (years)')
plt.ylabel('Weight (kg)')
plt.grid(True)
plt.show()

# 4. Bar Chart: Height of Individuals
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['Height'], color='green')
plt.title('Bar Chart of Individual Height')
plt.xlabel('Name')
plt.ylabel('Height (cm)')
plt.show()
# Out:
#     Name  Age  Height  Weight
# 0  kiran   25     145      45
# 1   arun   30     151      55
# 2  vijay   35     165      65
# 3  varun   40     173      75
